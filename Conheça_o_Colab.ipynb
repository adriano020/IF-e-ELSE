# %% [markdown]
# <a href="https://colab.research.google.com/github/adriano020/IF-e-ELSE/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input('digite sua idade:'))
if idade <= 16:
  print('voce e menor de idade')
elif idade >= 16 and idade < 18:
  print('voto opcional')
elif idade >= 18 and idade <=72:
  print('voto obrigatorio')
elif idade > 72:
  print('voto opcional')
# Out:
# digite sua idade:75
# voto opcional

# %%
usuario = str(input('digite seu email:'))
senha = str(input('digite sua senha:'))
if usuario == 'adriano020' and senha == '1315':
  print('acesso permitido')
else:
  print('usuario negado!')
# Out:
# digite seu email:adriano020
# digite sua senha:1315
# acesso permitido

# %%
usuario = str(input('digite o usuario:'))
senha = str(input('digite sua senha:'))
if usuario == 'admin' and senha =='1315':
  print('acesso permitido')
else:
  print('usuario negado!')
# Out:
# digite o usuario:admin
# digite sua senha:1315
# acesso permitido

# %%
entrega = input('digite o tipo de entrega:')
if entrega == 'padrao':
  print('entrega padrao: R$10,00')
elif entrega == 'expresso':
  print('entrega expresso: R$20,00')
else:
  print('opçao de entrega invalida')
# Out:
# digite o tipo de entrega:expresso
# entrega expresso: R$20,00
